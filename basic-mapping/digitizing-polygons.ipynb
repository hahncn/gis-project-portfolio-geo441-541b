# %% [markdown]
# <a href="https://colab.research.google.com/github/hahncn/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/digitizing-polygons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Entry & Digitizing**

# %% [markdown]
# Created by Claudia Hahn
#
# 09/20/2025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ##**Digitized Subdivision Map**

# %% [markdown]
# Below is a map of the digitized subdivision prepared following the Week 4 Assignment Guide
#
# ```markdown
# [https://drive.google.com/file/d/19MKKoF176ky5GKL4aA6bIcsWAYQBuE51/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=19MKKoF176ky5GKL4aA6bIcsWAYQBuE51]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](revised link)
# ```
#
# <mark>Insert the map below:</mark>
# ![digitizing polygons](https://drive.google.com/uc?export=view&id=19MKKoF176ky5GKL4aA6bIcsWAYQBuE51)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 4 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
